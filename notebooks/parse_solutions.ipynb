# %%
from app.parsers import parse_sections, get_paragraphs

# %%
with open("data/solutions.md") as file:
    content = file.read()

# %%
paragraphs = list(get_paragraphs(content))

# %%
paragraphs[0]
# Out:
# ('1',
#  '',
#  {'number': '2',
#   'title': 'Interpretations of Probability',
# ...
